# %%
# Steam Games Analysis
# Data source: SteamSpy API via Kaggle
# Author: David

import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv(r"C:\Users\david\Documents\Data Science\Steam-Analysis\steam_games_dataset.csv")

print("Dataset loaded successfully!")
print("Rows:", df.shape[0])
print("Columns:", df.shape[1])
# Out:
# Dataset loaded successfully!
# Rows: 10000
# Columns: 17

# %%
import shutil
import os

# Move the notebook to your project folder
shutil.move(
    r"C:\Users\david\Steam Game Analysis.ipynb",
    r"C:\Users\david\Documents\Data Science\Steam-Analysis\Steam Game Analysis.ipynb"
)

print("Notebook moved successfully!")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\shutil.py:856, in move(src, dst, copy_function)
#     855 try:
# --> 856     os.rename(src, real_dst)
#     857 except OSError:
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'C:\\Users\\david\\Steam Game Analysis.ipynb' -> 'C:\\Users\\david\\Documents\\Data Science\\Steam-Analysis\\Steam Game Analysis.ipynb'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 5
#       1 import shutil
#       2 import os
#       3
#       4 # Move the notebook to your project folder
# ----> 5 shutil.move(
#       6     r"C:\Users\david\Steam Game Analysis.ipynb",
# ...
